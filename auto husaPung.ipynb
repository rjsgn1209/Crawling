# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time

# %%
driver = webdriver.Chrome()
driver.get("https://wf.hunet.co.kr/?_emk_keyword=%ED%9C%B4%EC%82%AC%ED%8F%89&utm_source=google&utm_medium=cpc&utm_campaign=brand&utm_content=pc&utm_term=%ED%9C%B4%EC%82%AC%ED%8F%89&gclid=CjwKCAjwwsmLBhACEiwANq-tXKVgctynWpDLO_jdPMS3ohQatjiOGSXvKPhEtGhkbcASxpfLce_aPRoCHPQQAvD_BwE")

# %%
elem = driver.find_element_by_link_text("My강의실")
elem.click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_5852/455137982.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_link_text("My강의실")

# %%
elem = driver.find_element_by_id("txtPkiUserId")
elem.send_keys("rjsgn1209")
elem.send_keys(Keys.RETURN)
driver.current_url
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_5852/1940017532.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_id("txtPkiUserId")
# 'https://wfmember.hunet.co.kr/Login/Login.aspx?ReturnUrl=https%3a%2f%2fwf.hunet.co.kr%2fMyClass%2fClassRoom'

# %%
iframe = driver.find_element_by_id('cont')
driver.switch_to.frame(iframe)

elem = driver.find_element_by_xpath('//*[@id="playerVer1"]/div[2]/div[2]/a').click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_5852/2867165486.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   iframe = driver.find_element_by_id('cont')
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_5852/2867165486.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_xpath('//*[@id="playerVer1"]/div[2]/div[2]/a').click()

# %%
elem = driver.find_element_by_id("certPwd")
elem.send_keys("Bghjbghj1021@")
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_5852/3188069171.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_id("certPwd")

# %%
elem = driver.find_element_by_xpath('//*[@id="nx-cert-select"]/div[4]/button[1]').click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_5852/480058986.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_xpath('//*[@id="nx-cert-select"]/div[4]/button[1]').click()

# %%
elem = driver.find_elements_by_class_name("btn-study")
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
imgs = soup.select("td img")
dic = {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7: [], 8: []}
x = 1
a = 1
for i in range(len(imgs)):
    if a % 4 == 0:
        a = 1
        x += 1
    if imgs[i]['alt'] == "Y":
        dic[x].append(imgs[i]['alt'])
dic
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_5852/607218485.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   elem = driver.find_elements_by_class_name("btn-study")
# {1: ['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y'],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: [],
#  7: [],
#  8: []}

# %%
driver.get("https://seumstudy.hunet.co.kr/Course/StudyHome.aspx")
elem = driver.find_element_by_id("goStudy").click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_5852/3682724448.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_id("goStudy").click()
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5852/3682724448.py in <module>
#       1 driver.get("https://seumstudy.hunet.co.kr/Course/StudyHome.aspx")
# ----> 2 elem = driver.find_element_by_id("goStudy").click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     470             stacklevel=2,
#     471         )
# --> 472         return self.find_element(by=By.ID, value=id_)
#     473
#     474     def find_elements_by_id(self, id_) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
# ...

# %%
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")
trs = soup.select('#aspnetForm > table > tbody > tr > td > table:nth-child(2) > tbody > tr > td > table > tbody > tr > td > table > tbody > tr > td:nth-child(2) > table > tbody > tr > td:nth-child(2) > table.tbl_pro > tbody > tr')

for tr in trs[1:]:
    num = int(tr.select("span")[0].text)
    if tr.select("img"):
        src = tr.select("img")[0]['src']
        if src == "/images/bank/btn_study.gif":
            print("하자")

# %%
num = 20
print(f"https://seumstudy.hunet.co.kr/Study/ContentsV3/Home.aspx?userId=rjsgn1209&companySeq=0&processCd=SLSP00465&processYear=2021&processTerm=21111&courseCd=SLSC00457&takeCourseSeq=442225&chapterNo=0{99 + num}&frameNo=1&frameType=ft01&indexNo={num-1}&progressNo={num-1}&studyStartFirstDay=&studyStartFrameDay=&appYn=N&tbankYn=N")
# driver.get(f"https://seumstudy.hunet.co.kr/Study/ContentsV3/Home.aspx?userId=rjsgn1209&companySeq=0&processCd=SLSP00465&processYear=2021&processTerm=21111&courseCd=SLSC00457&takeCourseSeq=442225&chapterNo={99 + num}&frameNo=1&frameType=ft01&indexNo={num-1}&progressNo={num-1}&studyStartFirstDay=&studyStartFrameDay=&appYn=N&tbankYn=N")
# Out:
# https://seumstudy.hunet.co.kr/Study/ContentsV3/Home.aspx?userId=rjsgn1209&companySeq=0&processCd=SLSP00465&processYear=2021&processTerm=21111&courseCd=SLSC00457&takeCourseSeq=442225&chapterNo=0119&frameNo=1&frameType=ft01&indexNo=19&progressNo=19&studyStartFirstDay=&studyStartFrameDay=&appYn=N&tbankYn=N

# %%
https://seumstudy.hunet.co.kr/Study/ContentsV3/Home.aspx?userId=rjsgn1209&companySeq=0&processCd=SLSP00465&processYear=2021&processTerm=21111&courseCd=SLSC00457&takeCourseSeq=442225&chapterNo=119&frameNo=1&frameType=ft01&indexNo=19&progressNo=19&studyStartFirstDay=&studyStartFrameDay=&appYn=N&tbankYn=N
https://seumstudy.hunet.co.kr/Study/ContentsV3/Home.aspx?userId=rjsgn1209&companySeq=0&processCd=SLSP00465&processYear=2021&processTerm=21111&courseCd=SLSC00457&takeCourseSeq=442225&chapterNo=119&frameNo=1&frameType=ft01&indexNo=19&progressNo=19&studyStartFirstDay=&studyStartFrameDay=&appYn=N&tbankYn=N
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml"><head><script>var timeServer2 = new Date(\'January 21, 2022 18:28:17\');</script>\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=euc-kr"><title>\n\t휴사평 학습창\n</title><link href="/common/css/style.css" rel="stylesheet" type="text/css"><link href="/common/Smart_Editor/css/style.css" rel="stylesheet" type="text/css">\n\t<script language="javascript" src="/common/js/script.js"></script>\n\t<script language="javascript" src="/common/js/NChecker.js"></script>\n\t<script language="javascript" src="/common/js/CommonLink.js"></script>\n\t\n\t<script src="/common/js/jquery-1.4.2.min.js" type="text/javascript"></script> \n\n<script language="javascript" type="text/javascript">\n\n\nfunction fnChangeProcessPop(param){\n\tself.opener = self; self.close();\n\tpopCwin("/StudyLoadingCheck.aspx" + param ,"processpop","929","700","yes");\n}\n\n//학습수료 축하 팝업\n//2010.09.29 장형일\nfunction goPopCongratulation() {    \n    var servey = \'False\';
# ...
